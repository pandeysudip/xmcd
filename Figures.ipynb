# %%
#Load needed python routines

from matplotlib import pyplot as plt
import xrayutilities as xu
from scipy import misc
import os
import numpy as np
import pandas as pd
import peakutils
from matplotlib import rcParams
from matplotlib import patches
import sys

# %%
#for all three directions
field_100 = np.array([0.1,1,2,3,4])   #m4 and M5 edges
Pk_XMCD_Er_100=[-3.84624894e-04, -3.73827085e-01, -5.19166316e-01, -6.18548153e-01,
       -6.65782820e-01]
Pk_XMCD_Pr_100=[-0.03919603,  0.16458928, 0.08590154, -0.04909007, -0.07269929]


field_110 =  np.arange(0,5,.5)  
Pk_XMCD_Er_110=[-0.06879348, -0.23322694, -0.36589054, -0.46110892, -0.52840334,
       -0.57905163, -0.61949031, -0.64628509, -0.67383275, -0.69609997]
Pk_XMCD_Pr_110=[0.04689544, 0.03099175, 0.01955765, 0.00429811,-0.01571424,
       -0.0353759 , -0.05818153, -0.08028985, -0.09575876, -0.11090152]

field_111 =  np.array([0.1,0.5,1,1.5,2,3,4,5]) 
Pk_XMCD_Er_111=[2.35092732e-01,-2.97925768e-01, -5.11103670e-01, -5.99571622e-01,
       -6.60525587e-01, -7.29428837e-01, -7.80496312e-01, -7.97060643e-01]
Pk_XMCD_Pr_111=[-0.15457913,0.12271076, 0.14582914, 0.14724826, 0.10349362,
       0.13883834, 0.06325561, 0.02301482]

# %%
#plot for all three directions
fig,ax = plt.subplots(1,1,figsize=(10,7))
ax.set_ylabel('XMCD')
ax.set_xlabel('Field (T)')
ax.plot(field_100,Pk_XMCD_Er_100, 'd',label='Er_100',color='r',markersize=12)
ax.plot(field_100,Pk_XMCD_Pr_100,'d', label='Pr_100', color='k',markersize=12)
ax.plot(field_110,Pk_XMCD_Er_110, 'X',label='Er_110', color='m',markersize=12)
ax.plot(field_110,Pk_XMCD_Pr_110,'X',label='Pr_110', color='b',markersize=12)  
ax.plot(field_111,Pk_XMCD_Er_111, 'p',label='Er_111', color='darkred',markersize=12)
ax.plot(field_111,Pk_XMCD_Pr_111, 'p',label='Pr_111', color='g',markersize=12)
ax.axhline(0,color='k')
ax.legend(frameon=False)

# %%
#for all three directions

temp_100 = np.arange(7,33,3)
Pk_XMCD_Pr_100=[0.02363058, 0.0230728 , 0.02253117, 0.02304029, 0.02391649,
       0.02583746, 0.02957578, 0.03157042, 0.02925554]
Pk_XMCD_Er_100=[-0.5251221 , -0.48371482, -0.42527983, -0.38111355, -0.32974749,
       -0.28092163, -0.23076905, -0.19310871, -0.18027879]


temp_110 = np.arange(7,33,3)
Pk_XMCD_Pr_110=[-0.02079859, -0.01922973, -0.01820884, -0.02048718, -0.02636494,
       -0.03923559, -0.05720246, -0.05070271, -0.04057772]
Pk_XMCD_Er_110=[-0.5215139 , -0.47903757, -0.43134466, -0.38124422, -0.33057056,
       -0.27682731, -0.22517927, -0.20298239, -0.18800867]


temp_111 = np.array([7,10,13,16,19,22,24,25,26,28,31])
Pk_XMCD_Er_111=[-0.65442028, -0.62097945, -0.57664963, -0.52202922, -0.46183675,
       -0.39249523, -0.19873861, -0.20493182, -0.22654949, -0.203262  ,
       -0.19776286]
Pk_XMCD_Pr_111=[0.12026932, 0.12010687, 0.11526991, 0.10291609, 0.08631737,
       0.04862451,-0.09596869, -0.06542853,-0.06409981, -0.08411955,
       -0.04638494]

# %%
#for all three directions
fig,ax = plt.subplots(1,1,figsize=(10,7))
ax.set_ylabel('XMCD')
ax.set_xlabel('Temp (K)')
ax.plot(temp_100,Pk_XMCD_Er_100, 'd',label='Er_100',color='r',markersize=12)
ax.plot(temp_100,Pk_XMCD_Pr_100,'d', label='Pr_100', color='k',markersize=12)
ax.plot(temp_110,Pk_XMCD_Er_110, 'X',label='Er_110', color='m',markersize=12)
ax.plot(temp_110,Pk_XMCD_Pr_110,'X',label='Pr_110', color='b',markersize=12)  
ax.plot(temp_111,Pk_XMCD_Er_111, 'p',label='Er_111', color='darkred',markersize=12)
ax.plot(temp_111,Pk_XMCD_Pr_111, 'p',label='Pr_111', color='darkviolet',markersize=12)
ax.axhline(0,color='k')
ax.legend(frameon=False)
